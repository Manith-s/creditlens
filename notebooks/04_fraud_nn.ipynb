# %% [markdown]
# # 04 · Fraud: GBM vs PyTorch vs Keras
#
# Leakage-safe imbalance handling; evaluate on AUPRC/recall/MCC (not accuracy). Register the champion to MLflow.

# %%
import sys; sys.path.append('..')
from src.pipelines.run_fraud import run
summary = run()
summary['champion'], summary['metrics']

# %% [markdown]
# On tabular data the GBM typically wins — state that finding plainly. Note AUC is high while AUPRC is the real story under 0.3% fraud.
