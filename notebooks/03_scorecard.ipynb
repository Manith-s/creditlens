# %% [markdown]
# # 03 · Scorecard + GBM + SHAP
#
# Fit a WOE-logistic scorecard (PDO scaling), train a GBM, document the honest AUC lift, and generate a Reg B adverse-action notice from SHAP.

# %%
import sys; sys.path.append('..')
from src.pipelines.run_credit import run
out = run()
out['summary']

# %% [markdown]
# The `auc_lift` comes from a nonlinear interaction the additive scorecard can't capture but the GBM can. See `artifacts/sample_adverse_action_notice.txt`.
